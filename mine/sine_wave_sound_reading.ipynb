# %%
### Source: https://www.youtube.com/watch?v=6n9ybiwnbT8
import scipy.io.wavfile as sound_reader
import matplotlib.pyplot as plotter

# %%
# Reading file
[sample_rate, data] = sound_reader.read('sound_file.wav')
print(data)
# Out:
# [[  -78   -25]
#  [  -85   -27]
#  [  -83   -24]
#  ...
#  [-2980 -1606]
#  [-1388   364]
#  [ -857   340]]

# %%
# ????
data = data[:,1]

# %%
# Plot file
plotter.plot(data)
